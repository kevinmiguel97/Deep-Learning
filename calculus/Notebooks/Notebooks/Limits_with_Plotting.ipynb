# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $ \lim\limits_{x \to \infty} \frac{\ln x}{x} = 0$

# %%
x = np.linspace(1, 1000, 10000)
y = np.log(x) / x

# %%
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.plot(x, y);

# %% [markdown]
# **$ \lim\limits_{x \to \infty} \frac{x^2 - 3x + 5}{2 x^2 + x + 1} = \frac{1}{2}$**

# %%
x = np.linspace(1, 300, 10000)
y = (x ** 2 - 3 * x + 5) / (2 * x ** 2 + x + 1)

# %%
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.plot(x, y);

# %% [markdown]
# **$ \lim\limits_{x \to 0} \frac{\sin(x)}{x} = 1$**

# %%
x = np.linspace(-3 * np.pi, 3 * np.pi, 1000)
y = np.sin(x) / x

# %%
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.plot(x, y);

# %% [markdown]
# **$ \lim\limits_{x \to 0} \frac{\cos(x) - 1}{x} = 0$**

# %%
x = np.linspace(-3 * np.pi, 3 * np.pi, 1000)
y = (np.cos(x) - 1) / x

# %%
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.plot(x, y);

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=KAHmaQAnZ5YL60VOLHThGA&n=Limits+with+Plotting)
